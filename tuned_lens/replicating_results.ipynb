# %%
from datasets import load_dataset, DatasetDict
from data import silence_datasets_messages, chunk_and_tokenize
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import AutoModelForCausalLM
from nn.lenses import TunedLens, LogitLens
import sys
from causal.intervention import estimate_effects
sys.path.append('C:/Users/nicol/OneDrive - Politecnico di Milano/Desktop/tuned-lens/tuned_lens')
sys.path.append('C:/Users/nicol/OneDrive - Politecnico di Milano/Desktop/tuned-lens')

# %%
dataset = load_dataset("wikitext", "wikitext-2-raw-v1")
assert isinstance(dataset, DatasetDict)
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-160m")
dataset = chunk_and_tokenize(dataset, tokenizer)
token_ids =  dataset['train'][:10]['input_ids'][:, :128]

# %%
pythia_160M_lens = TunedLens(pythia_160M_model)

# %%
logit_lens_effects = estimate_effects(pythia_160M_model, token_ids)
# Out:
# Applying:   0%|          | 0/127 [00:00<?, ?token/s]

# %%
logit_lens_effects
# Out:
# InterventionResult(loss_diffs=tensor([[[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [-3.9062e-02, -1.9531e+00,  1.1016e+00,  ..., -8.4375e-01,
#                   nan, -3.2812e-01],
#          [ 5.4219e+00,  9.3750e-02, -6.4062e-01,  ...,  1.6953e+00,
#            6.2500e-01,  4.3438e+00],
#          ...,
#          [        nan, -7.6660e-02, -1.0547e-01,  ...,  1.6748e-01,
#           -4.1284e-01, -2.6123e-01],
#          [ 2.1523e+00, -3.0469e-01, -4.1016e-01,  ...,         nan,
#            2.2930e+00, -1.3672e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
# ...

# %%
import torch

# %%
logit_lens_effects.line()

# %%
logit_lens_effects = estimate_effects(pythia_160M_model, token_ids, lens= pythia_160M_lens)
# Out:
# Applying:   0%|          | 0/127 [00:00<?, ?token/s]

# %%
logit_lens_effects.line()

# %%
pythia_160M_lens_logit = LogitLens(pythia_160M_model)

# %%
logit_lens_effects = estimate_effects(pythia_160M_model, token_ids, lens= pythia_160M_lens_logit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 logit_lens_effects = estimate_effects(pythia_160M_model, token_ids, lens= pythia_160M_lens_logit)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\amp\autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# ...

# %%
tuned_lens_effects = estimate_effects(pythia_160M_model, token_ids, lens= pythia_160M_lens)

# %%
tuned_lens_effects.line()

# %%
from tuned_lens.causal.intervention import estimate_effects

pythia_160M_model = AutoModelForCausalLM.from_pretrained("EleutherAI/pythia-160m")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-160m")
pythia_125M_lens = TunedLens(pythia_160M_model)


processed = chunk_and_tokenize(dataset, tokenizer)

logit_lens_effects = estimate_effects(model)
